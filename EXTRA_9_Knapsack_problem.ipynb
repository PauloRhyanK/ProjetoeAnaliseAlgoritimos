# %% [markdown]
# <a href="https://colab.research.google.com/github/PauloRhyanK/ProjetoeAnaliseAlgoritimos/blob/main/EXTRA_9_Knapsack_problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <html>
#   <body>
#     <header></header>
#         <CENTER>
#           <img src="https://uvv.br/wp-content/themes/core/dist/images/Logo@2x.png" alt="UVV-LOGO" style = width="100px"; height="100px">
#         </CENTER>
#         <CENTER><b>ESTRATÉGIA DE PROJETO</b></CENTER>
#         <CENTER><b>KNAPSACK PROBLEM</b></CENTER><br/>

# %% [markdown]
# NOME:

# %% [markdown]
# LINK PARA MEU PRÓPRIO TRABALHO: [texto do link](https://colab.research.google.com/drive/15rdT4CtOlXaAaR895NS2Gjzw35b1nvsN?usp=sharing)

# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Bibliotecas / funções:

# %%
import numpy as np
import pandas as pd
import math

# %%
N = 5    # QUANTIDADE DE OBJETOS
C = 100 # CAPACIDADE MÁXIMA: QUILOGRAMAS
# SOLUÇÃO: Muitas saídas possíveis
valor = np.zeros(N, dtype=int)
massa = np.zeros(N, dtype=int)
total = np.zeros((N, N), dtype=int)
quantidade = np.zeros((N, N), dtype=int)

# %%
valor = np.random.choice(np.arange(10, 31), N, replace=False)
valor
# Out:
# array([16, 17, 19, 13, 20])

# %%
massa = np.random.choice(np.arange(1, 16), N, replace=False)
massa
# Out:
# array([12,  6,  3, 15,  5])

# %% [markdown]
# # QUESTÃO 1:

# %% [markdown]
# Faça a implemetação da função (def, conforme o protótipo): Knapsack_problem(C, N) por força bruta, considerando todas as permutações possíveis entre os objetos.

# %%
# SOLUÇÃO ÓTIMA GLOBAL
def Knapsack_problem(C, N):

# %% [markdown]
# # QUESTÃO 2:

# %% [markdown]
# Faça a implemetação da função (def, conforme o protótipo): Knapsack_problem(C, N) por estratégia gananciosa.

# %%
'''
CARACTERÍSTICAS:
  -> Escolha Gananciosa: Maior Relação: Valor / Massa = R$ / Kg
  -> SOLUÇÃO ÓTIMA LOCAL
'''
